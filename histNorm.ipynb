# %%
import numpy as np
import matplotlib.pyplot as plt

#position
pos = 100
#scale
scale = 10
#size
size = 5000

values = np.random.normal(pos, scale, size)
print(values)

#histogram
plt.hist(values, 100)
plt.show()
# Out:
# [108.21035929 111.10337426 105.27499804 ... 103.27769989  98.53027569
#   90.03798603]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

x_axis = np.arange(-100, 100, 0.01)
#Calculate the mean
mean = statistics.mean(x_axis)
#Calculate the standard deviation
sd = statistics.stdev(x_axis)
print(sd)

plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()
# Out:
# 57.73647027662334
