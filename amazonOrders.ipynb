# %%
import numpy as np
import csv, matplotlib.pyplot as plt
import os
os.system('clear')

import csv
file = open('amazonOrderList.csv')

amazonList = csv.reader(file)
# header = next(amazonList)
listData = []
header = next(amazonList)
for row in amazonList:
    listData.append(row)

print(listData)

# priceColumn = dataset[:, 12].astype(int)
# priceSum = priceColumn[:, 12].sum()
# print(priceSum)
# Out:
# [['02/14/17', '112-8113601-7340212', 'Perfect Samplers Coffee Pod, Dark Roast & Bold Flavors, Single Serve Cups for Keurig K Cup Machines, Robust Assortment, Variety Pack, 40 Count', 'COFFEE', 'B00SUE0FDA', '50201700', 'Amazon.com', '', 'new', 'Perfect Samplers', '', '$0.00', '$27.90', '1', 'American Express - 1001 and Gift Certificate/Card', '', '', 'ray.dhanani@gmail.com', '02/14/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA188929916000)', '$27.90', '$0.00', '$27.90', '', '', '', 'Ray Dhanani', 'USD', ''], ['02/14/17', '112-4816083-5269861', '', '', 'B00KS94JSC', '', 'Amazon.com', '', 'new', 'Terrific Deal, Inc.', 'Women-Owned Small Business', '$0.00', '$37.75', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '02/14/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA188929916000)', '$37.75', '$0.00', '$37.75', '', '', '', 'Ray Dhanani', 'USD', ''], ['02/15/17', '112-3613532-4456213', 'Pilot FriXion Ball Knock Retractable Gel Ink Pen, 0.7 mm, 10 Color Set (LFBK-230F-10C)', 'WRITING_INSTRUMENT', 'B005ZP8QX8', '44121721', 'Amazon.com', '', 'new', 'Amazon.com', '', '$40.00', '$18.13', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '02/16/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA190223354000)', '$18.13', '$1.50', '$19.63', '', '', '', 'Ray Dhanani', 'USD', ''], ['02/19/17', '112-7147511-8544225', '', '', 'B01E06YG18', '', 'Amazon.com', '', 'new', 'LEOVERA INC', '', '$129.99', '$35.99', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '02/19/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA192937322000)', '$35.99', '$0.00', '$35.99', '', '', '', 'Ray Dhanani', 'USD', ''], ['04/03/17', '111-6572626-3689866', 'Zittop Amber Fine Tooth Portable Two Side Plastic Hair Comb 2 Pcs', 'HAIR_COMB', 'B00A8VIUUS', '53131600', 'Amazon.com', '', 'new', 'SGILETOY OFFICIAL', '', '$0.00', '$1.74', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '04/05/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'Turkey postal(8000210013519)', '$1.74', '$0.00', '$1.74', '', '', '', 'Ray Dhanani', 'USD', ''], ['04/10/17', '111-4990107-5793868', '', '', 'B01B2JHPPA', '', 'Amazon.com', '', 'new', 'Ibuywill', '', '$0.00', '$6.99', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '04/12/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA240922150000)', '$6.99', '$0.00', '$6.99', '', '', '', 'Ray Dhanani', 'USD', ''], ['04/11/17', '112-1809355-1101059', 'SUGART - WHITE SUGAR - 500 Individual Serving Stick Packets - U Parve/Kosher', 'SUGAR', 'B01D0HHAHK', '50161500', 'Amazon.com', '', 'new', 'SUGART', '', '$0.00', '$12.00', '4', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '04/11/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'UPS(1Z0725AF0394954280)', '$48.00', '$0.00', '$48.00', '', '', '', 'Ray Dhanani', 'USD', ''], ['04/19/17', '112-3113996-6792240', 'Pilot FriXion Ball Knock Retractable Gel Ink Pen, 0.7 mm, 10 Color Set (LFBK-230F-10C)', 'WRITING_INSTRUMENT', 'B005ZP8QX8', '44121721', 'Amazon.com', '', 'new', 'Amazon.com', '', '$40.00', '$18.92', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '04/20/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA250051490000)', '$18.92', '$1.56', '$20.48', '', '', '', 'Ray Dhanani', 'USD', ''], ['04/20/17', '112-1017831-9101038', 'Canon 104, Black Toner Cartridge (0263B001BA)', 'LASER_PRINTER_TONER', 'B000B02BEM', '44103103', 'Amazon.com', '', 'new', 'Amazon.com', '', '$110.00', '$65.01', '1', 'American Express - 1001', '', '', 'ray.dhanani@gmail.com', '04/21/17', 'Ray Dhanani', '6509 SUDBURY RD', '', 'PLANO', 'TX', '75024-7413', 'Shipped', 'AMZN_US(TBA250783472000) ...
